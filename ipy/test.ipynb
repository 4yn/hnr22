# %%
# %load_ext watcher
# Out:
# The watcher extension is already loaded. To reload it, use:
#   %reload_ext watcher

# %%
secret = "testing123"

# %% [markdown]
# Firstly, implement the following function to find the $n$-th fibonacci number:

# %%
def fibo(n):
    # Write your implementation here!
    return 0

# %%
fibo(105)
# Out:
# 0

# %% [markdown]
# Next, plot some random differential equation!

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# %%capture
# Write your plot here! Do not change the next two lines.
fig, ax = plt.subplots(figsize=(16,12))

nx, ny = .3, .3
x = np.arange(-6, 6, nx)
y = np.arange(-6, 6, ny)
X, Y = np.meshgrid(x, y)

dx = -3/2 * X + Y
dy = -1/4 * X - 1/2 * Y

plt.quiver(X, Y, dx, dy, 
           color='Teal', 
           headlength=7)

plt.streamplot(X, Y, dx, dy, color='blue', density=1., cmap='jet', arrowsize=1)

# %%
fig.canvas.draw()
Image.frombytes('RGB', fig.canvas.get_width_height(), fig.canvas.tostring_rgb())
# Out:
# <PIL.Image.Image image mode=RGB size=1152x864 at 0x7F4A2CD930D0>

# %%
2 + 4
# Out:
# 6
