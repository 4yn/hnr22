# %%
# %load_ext watcher
# Out:
# The watcher extension is already loaded. To reload it, use:
#   %reload_ext watcher

# %%
secret = "jiachengiscool"

# %%
def fibo(n):
    if (n == 0):
        return 0
    if (n == 1):
        return 1
    return fibo(n-1) + fibo(n-2)

# %%
from matplotlib.pyplot import cm
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

nx, ny = .3, .3
x = np.arange(-6, 6, nx)
y = np.arange(-6, 6, ny)
X, Y = np.meshgrid(x, y)

dx = -3/2 * X + Y
dy = -1/4 * X - 1/2 * Y

plot = plt.figure(figsize=(16,12))
plt.quiver(X, Y, dx, dy, 
           color='Teal', 
           headlength=7)

plt.streamplot(X, Y, dx, dy, color='blue', density=1., cmap='jet', arrowsize=1)
plot.canvas.draw()
Image.frombytes('RGB', plot.canvas.get_width_height(), plot.canvas.tostring_rgb())
# Out:
# <PIL.Image.Image image mode=RGB size=1152x864 at 0x7F2F20895C10>
# <ExecutionResult object at 7f2f234516a0, execution_count=4 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7f2f23461f70, raw_cell="from matplotlib.pyplot import cm
# import matplotlib.." store_history=True silent=False shell_futures=True> result=<PIL.Image.Image image mode=RGB size=1152x864 at 0x7F2F20895C10>>
