# %%
# %load_ext pynoculars_local
# Out:
# {'room': '0001', 'secret': 'ok', 'idx': 1, 'code': '%load_ext pynoculars_local', 'ok': True, 'stdout': '', 'stderr': '', 'outputs': []}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# {'room': '0001', 'secret': 'ok', 'idx': 2, 'code': 'import matplotlib.pyplot as plt\n%matplotlib inline', 'ok': True, 'stdout': '', 'stderr': '', 'outputs': []}

# %%
plt.scatter([0, 1, 2, 3], [2, 0, 1, 4])
# Out:
# {'room': '0001', 'secret': 'ok', 'idx': 3, 'code': 'plt.scatter([0, 1, 2, 3], [2, 0, 1, 4])', 'ok': True, 'stdout': '', 'stderr': '', 'outputs': [{'text/plain': '<Figure size 432x288 with 1 Axes>', 'image/png': '...'}, {'text/plain': '<matplotlib.collections.PathCollection at 0x7f6688c7a550>'}]}

# %% [markdown]
# # Learn to Code!
#
# It's so fun to learn to code. Don't worry, this notebook is completely local. ~~Please do not disconnect from the internet~~ There's nobody judging you or anything!

# %% [markdown]
# ## Getting started
#
# Let's start with something simple. How about some counting? I have A apples and B bananas. Write me a function that tells me how much fruit I have!

# %%
def add(a, b):
    # Write your implementation here
    return 0

# Don't change the part below
print(add(1, 2))
print(add(5, 0))
# Out:
# 0
# 0
# {'room': '0001', 'secret': 'ok', 'idx': 4, 'code': "def add(a, b):\n    # Write your implementation here\n    return 0\n\n# Don't change the part below\nprint(add(1, 2))\nprint(add(5, 0))", 'ok': True, 'stdout': '0\n0\n', 'stderr': '', 'outputs': []}

# %% [markdown]
# ## A bit harder
#
# I'm writing a speech!!1!! But ! keep wr!t!ng exclamation points!!! Can you remove all of them?

# %%
# Question 2 (Do not modify this line!!! 😠)
def remove_exclamations(speech):
    # Your implementation here!
    return "!!!"

# Don't change this!!!!!!!!!!
remove_exclamations("Wow!!! I can't believe it!!!!!!")
remove_exclamations("!I!t!h!i!!n!k!!t!h!!i!s!a!p!r!o!!b!l!!!e!m!!!")
# Out:
# '!!!'
# '!!!'
# {'room': '0001', 'secret': 'ok', 'idx': 5, 'code': '# Question 2 (Do not modify this line!!! 😠)\ndef remove_exclamations(speech):\n    # Your implementation here!\n    return "!!!"\n\n# Don\'t change this!!!!!!!!!!\nremove_exclamations("Wow!!! I can\'t believe it!!!!!!")\nremove_exclamations("!I!t!h!i!!n!k!!t!h!!i!s!a!p!r!o!!b!l!!!e!m!!!")', 'ok': True, 'stdout': '', 'stderr': '', 'outputs': [{'text/plain': "'!!!'"}]}

# %% [markdown]
# ## Fun with graphs!
#
# Plot some happy little curves! Do it on the same graph!
#
# $$x = 0.2 \sin{\theta} - 1, y = 0.2 \cos{\theta} + 1, -\pi \leq \theta \leq \pi,$$
# $$x = 0.2 \sin{\theta} + 1, y = 0.2 \cos{\theta} + 1, -\pi \leq \theta \leq \pi,$$
# $$x = 2 \cos{\theta} - 3, y = 2 \sin{\theta}, -\pi/6 \leq \theta \leq \pi/6,$$

# %%
# Some imports to help out!
import matplotlib.pyplot as plt
import numpy as np
# Out:
# {'room': '0001', 'secret': 'sdqwd', 'idx': 2, 'code': '# Some imports to help out!\nimport matplotlib.pyplot as plt\nimport numpy as np', 'ok': True, 'stdout': 'None\n', 'stderr': '', 'outputs': []}

# %%
fig = plt.figure(3, figsize=(16,12))
plt.xlim([-2, 2])
plt.ylim([-2, 2])

# Write your happy little plot here! Here's one to get you started.

theta1 = np.linspace(-np.pi, np.pi, 100)
X1 = 0.2 * np.sin(theta1) - 1
Y1 = 0.2 * np.cos(theta1) + 1
plt.plot(X1, Y1)

theta2 = np.linspace(-np.pi, np.pi, 100)
X2 = 0.2 * np.sin(theta2) + 1
Y2 = 0.2 * np.cos(theta2) + 1
plt.plot(X2, Y2)

theta3 = np.linspace(-np.pi / 4, np.pi / 4, 100)
X3 = 1.5 * np.sin(theta3)
Y3 = 1.5 * np.cos(theta3) - 2
plt.plot(X3, Y3)

fig
# Out:
# {'room': '0001', 'secret': 'sdqwd', 'idx': 7, 'code': "fig = plt.figure(3, figsize=(16,12))\nplt.xlim([-2, 2])\nplt.ylim([-2, 2])\n\n# Write your happy little plot here! Here's one to get you started.\n\ntheta1 = np.linspace(-np.pi, np.pi, 100)\nX1 = 0.2 * np.sin(theta1) - 1\nY1 = 0.2 * np.cos(theta1) + 1\nplt.plot(X1, Y1)\n\ntheta2 = np.linspace(-np.pi, np.pi, 100)\nX2 = 0.2 * np.sin(theta2) + 1\nY2 = 0.2 * np.cos(theta2) + 1\nplt.plot(X2, Y2)\n\ntheta3 = np.linspace(-np.pi / 4, np.pi / 4, 100)\nX3 = 1.5 * np.sin(theta3)\nY3 = 1.5 * np.cos(theta3) - 2\nplt.plot(X3, Y3)\n\nfig", 'ok': True, 'stdout': 'Figure(1152x864)\n!!!\n', 'stderr': '', 'outputs': [{'text/plain': '<Figure size 1152x864 with 1 Axes>', 'image/png': '...'}, {'text/plain': '<Figure size 1152x864 with 1 Axes>', 'image/png': '...'}, {'text/plain': '<Figure size 1152x864 with 1 Axes>', 'image/png': '...'}]}

# %%
fig = plt.figure(3, figsize=(16,12))
plt.bar([0, 1, 2], [2, 0, 1])

fig = plt.figure(3, figsize=(16,12))
# Out:
# {'room': '0001', 'secret': 'sdqwd', 'idx': 6, 'code': 'fig = plt.figure(3, figsize=(16,12))\nplt.bar([0, 1, 2], [2, 0, 1])\n\nfig = plt.figure(3, figsize=(16,12))', 'ok': True, 'stdout': 'None\n', 'stderr': '', 'outputs': [{'text/plain': '<Figure size 1152x864 with 1 Axes>', 'image/png': '...'}]}

# %%
3 + 5
# Out:
# 8
# {'room': '0001', 'secret': 'asd', 'idx': 6, 'code': '3 + 5', 'ok': True, 'stdout': '', 'stderr': '', 'outputs': [{'text/plain': '8'}]}
